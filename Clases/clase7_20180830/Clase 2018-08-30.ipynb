# %% [markdown]
# # 2018-08-30 (Jueves)
#
# ## Tarea 2. Entrega hoy 23:59 hrs.
#
# ## Reuniones proyecto
#
# ## "Vacaciones"
#
# ## Tarea 3: Martes 25 sept
#
# ## Propuesta de proyecto formal:  Jueves 27 sept
#
# ## Presentaciones Proyecto: 4 octubre
#
# ---
#
# ## Funciones
#
# En todo lenguaje de programación podemos definir funciones que toman inputs y entregan un output. Se puede pensar una función como una caja negra que toma los objetos que le pasamos, los transforma, analiza y procesa, y produce un nuevo output dado esas transformaciones, analisis y procesos.

# %%
def suma_uno(a):
    '''
    Esta función toma el parámetro "a" y le suma 1
    '''
    
    return a + 1

# %% [markdown]
# Ahora podemos usar nuestra funcion en cualquier parte

# %%
print(suma_uno(3))

#que deberia pasar aqui?
if suma_uno(7) == 8:
    print('no')
else:
    print('si')

# %% [markdown]
# Es importante que nuestras funciones estén bien documentadas y que sean lo más "comprensivas" posible, respecto a la variedad de situaciones en las que se pueden poner

# %%
print(suma_uno('1'))

# %% [markdown]
# La función anterior está mal definida, ya que arroja un error cuando se le entrega un input erroneo. Aquí hay varias opciones sobre qué hacer, lo mejor es siempre hacer explícita alguna situación puntual

# %%
def suma_uno_mejor(a):
    '''
    Input: "a", debe ser un número (int o float)
    Return: entrega un número (int o float)
    '''
    
    #primero, revisa el tipo de la variable "a"
    if type(a) not in [int, float]:
        print('Advertencia, input erroneo! Retornando "None"')
        return None
    
    #si el tipo esta ok, procede
    
    return a + 1

print(suma_uno_mejor('3'))
print(suma_uno_mejor(3))
print(suma_uno_mejor(3.3))

# %% [markdown]
# #### Parametros opcionales

# %% [markdown]
# Podemos definir funciones que tomen parametros opcionales, definiendo en la misma funcion cual sera el valor por defecto que tomará dicho parámetro cuando no definamos algún valor

# %%
def suma_delta(a, delta=1):
    '''
    Suma "delta" al número a. Si no entrega delta, se ocupa valor por defecto
    '''
    if type(a) not in (int, float):
        print('Advertencia, input erroneo')
        return None
    
    return a + delta

print(suma_delta(4, 4))
print(suma_delta(4))

# %%
# que pasara aqui?

print(suma_delta(4, True))

# %% [markdown]
# ### Comentario: Funciones y Kattis

# %% [markdown]
# ** Ejercicio en clase **
#
# Dadas nuestras impresionantes habilidades en automatización, nuestro jefe nos pidió ahora determinar cuántos y cuáles caracteres distintos tiene cada línea, para poder priorizar cuáles líneas se imprimen primero. Por razones de imprenta, se imprimen primero aquellas líneas con un ratio de (largo de linea) / (caracteres distintos) mayor.

# %%
# como sabemos programar, guardamos la definicion de la funcion "costo_de_linea" en 
# una "libreria" llamada "funciones_de_linea"

from funciones_de_linea import costo_de_linea

test_linea = 'hola Como Estas'

print(costo_de_linea(test_linea))
# Out:
# 270

# %% [markdown]
# Complete las funciones señaladas

# %%
def caracteres_distintos(linea):
    '''
    Input: linea de texto a imprimir
    Output: lista de caracteres distintos
    '''
    caracteres = []
    
    return caracteres

def ratio_impresion(linea):
    '''
    Input: linea de texto a imprimir
    Output: ratio entre largo de linea y numero de caracteres distintos
    '''
    ratio = None
    
    return ratio

# %% [markdown]
# Pruebe sus funciones

# %%
print(caracteres_distintos(test_linea))
print(ratio_impresion(test_linea))
# Out:
# []
# None

# %% [markdown]
# Pasó el tiempo y su jefe cada vez le pide más funciones para distintos cálculos relacionados a las líneas. Por lo demás, usted ha tenido que comenzar a capacitar a sus compañeros en cómo usar cada una de estas funciones. Otros compañeros, en tanto, han comenzado a modificar las funciones para considerar otros escenarios o realizar los cálculos de formas un tanto distintas, pero esto ha provocado que ciertas funciones, que dependían de aquellas, dejen de funcionar...
#
# Para resolver esto, usted comenzo a pensar en estandarizar el concepto de "que" es una "Linea" desde la perspectiva de la imprenta, que operaciones se pueden realizar sobre ella, y como esas operaciones estaran relacionadas entre si.

# %% [markdown]
# ## Datos no estructurados
#
# Con datos no estructurado me refiero a cualquier colección de información que no esté en formato de base de datos y sobre la cual queramos extraer información relevante para nuestro análisis. En las siguientes clases trabajaremos extrayendo información de 3 tipos:
#
# - HTML
# - Texto (usando Expresiones Regulares)
# - APIs
#
# ## 1. HTML
#
# HTML (Hypertext Markup Language) es el lenguaje estándar de páginas web. Dicho lenguaje permite estructurar y formatear documentos de texto a los cuales accedemos usualmente a través del explorador de internet (Chrome, Firefox, IExplorer, etc).
#
# La estructura típica de un documento HTML es la siguiente:
#
# ```html
# <!DOCTYPE html>
# <html>
#     <head>
#     <title>Page Title</title>
#     </head>
# <body>
#     <div>
#         <h1>My First Heading</h1>
#         <p>My first paragraph.</p>
#     </div>
# </body>
# </html>
# ```

# %% [markdown]
# #### Ejemplo 1. Puntaje alumnos en Kattis

# %%
# es importante correr esta celda solo 1 vez, para evitar hacer 
# muchos GET requests a la pagina de Kattis

import requests

base_url = 'https://open.kattis.com/universities/uc.cl'

# el metodo "get" de la libreria requests nos permite hacer una solicitud "get"
# al servidor señalado. Dicha libreria nos entrega un objeto "Response",
# que incluye información sobre la respuesta que tuvo nuestra solicitud

request = requests.get(base_url)

print(request.text)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
#     <meta charset="UTF-8" >
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <title>Pontifical Catholic University of Chile &ndash; Kattis, Kattis</title>
#
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.3/css/base/minified/jquery-ui.min.css" rel="stylesheet">
#
#     <script src="//ajax.googleapis.com/ajax/libs/jquery/1.10.1/jquery.min.js"></script>
#     <script src="//ajax.googleapis.com/ajax/libs/jqueryui/1.10.3/jquery-ui.min.js"></script>
#
#     <!-- Fonts/Icons -->
#     <link href="//cdnjs.cloudflare.com/ajax/libs/font-awesome/4.0.1/css/font-awesome.min.css" rel="stylesheet">
#
#     <link href="//fonts.googleapis.com/css?family=Open+Sans:400,300,300italic,400italic,600,600italic,700,800,700italic,800italic%7CMerriweather:400,400italic,700" rel="stylesheet" type="text/css">
#
#     <!-- Bootstrap CSS -->
#     <link href="//cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/3.3.5/css/bootstrap.min.css" rel="stylesheet">
#
#     <!-- Editable and Select2 -->
#     <link href="//cdnjs.cloudflare.com/ajax/libs/select2/3.4.8/select2.css" rel="stylesheet">
#
#     <link rel="shortcut icon" href="/favicon" />
#
#     <!-- Own CSS -->
#     <link rel="stylesheet" href="/css/system.css?a68c88">
#     <style type="text/css">
#           .header {
#          background-color: rgb(240,176,52);
#      }
#      .header .main-nav > ul > li.current:before {
#          border-bottom-color: rgb(240,176,52);
#      }
#
#           --div.page-content.clearfix.above-everything.alert.alert-danger { color: #31708f; background: #d9edf7; border-color: #bce8f1; }
#
#          </style>
#
#     <script type="text/javascript">
#         window.page_loaded_at = new Date();
#         jQuery.noConflict();
#         var $j = jQuery;
#     </script>
#
#     <script type="text/javascript">
#     jQuery.ns = function (namespace) {
#         var parts = namespace.split('.');
#         var last = window;
#         for (var i = 0; i < parts.length; i++) {
#             last = last[parts[i]] || (last[parts[i]] = {});
#         }
#         return last;
#     };
# </script>
#     <script>
# jQuery.extend(jQuery.ns('Kattis.error'), (function () {
#     var messages = {"INTERNAL_SERVER_ERROR":"Internal server error.","ACCESS_DENIED":"Access denied.","NOT_AUTHENTICATED":"Not authenticated.","METHOD_NOT_ALLOWED":"Method not allowed.","INVALID_JSON":"JSON cannot be decoded or encoded data is deeper than the recursion limit.","BAD_CSRF_TOKEN":"Token does not match session's csrf_token","SESSION_NAME_EMPTY":"Session's name must be non empty.","SESSION_START_TIME_EMPTY":"Session's start time must be non empty.","SESSION_START_TIME_PASSED":"Session's start time has already passed.","SESSION_DURATION_EMPTY":"Session's duration must be non empty.","SESSION_DURATION_NEGATIVE":"Session's duration must be a positive number.","SESSION_DURATION_EXCEEDED":"Maximum duration for the session was exceeded.","SESSION_ALREADY_STARTED":"The session has already started.","SESSION_ALREADY_FINISHED":"The session is already finished.","USER_CREATED_SESSION_DURATION_EXCEEDED":"Contest cannot be longer than 168 hours.","INVALID_SESSION_SHORTNAME":"Invalid shortname for the session.","INVALID_SESSION_CUTOFF":"Invalid cutoff for the session.","INVALID_USER_NAME":"Invalid username or email.","SESSION_NOT_FOUND":"No such session.","COURSE_NOT_FOUND":"No such course.","OFFERING_NOT_FOUND":"No such offering.","TEACHER_NOT_FOUND":"No such teacher.","TEACHER_CANNOT_REMOVE_SELF":"You may not remove yourself as a teacher unless you are an administrator.","AUTHOR_NOT_FOUND":"No such author.","JUDGE_NOT_FOUND":"No such judge.","JUDGE_ALREADY_EXIST":"The user is already a judge.","TEACHER_ALREADY_EXIST":"The user is already a teacher.","PROBLEM_NOT_FOUND":"No such problem.","TEAM_NOT_FOUND":"No such team.","SESSION_PROBLEM_ALREADY_EXIST":"The problem has been already added to the session.","SESSION_PROBLEM_DOES_NOT_EXIST":"The problem does not relate to the session.","PROBLEM_INDEX_NEGATIVE":"Problem index must be non negative.","AUTHOR_IS_CURRENT_TEAM_MEMBER":"The user you tried to add is already a member of the current team.","AUTHOR_IS_ANOTHER_TEAM_MEMBER":"The user you tried to add is already a member of another team in the current session.","AUTHOR_IS_JUDGE":"The user you tried to add is a judge.","AUTHOR_IS_NOT_TEAM_MEMBER":"The user you tried to remove is not a team member.","JUDGE_IS_TEAM_MEMBER":"The user you tried to add is a session team member or invitee.","SESSION_PUBLISHING_DENIED":"You do not have permission to publish this session.","CANNOT_PUBLISH_HISTORICAL_SESSION":"You cannot publish a session with a historical start time."};
#
#     return {
#         get_msg: function (error_code) {
#             return messages[error_code];
#         },
#
#         show_msg: function (base_message, error_code) {
#             if (error_code) {
#                 alert(base_message + ": " + this.get_msg(error_code));
#             } else {
#                 alert(base_message);
#             }
#         },
#
#         show_xhr_msg: function (elem, jqXHR) {
#             var base_message = elem.data('fail-msg');
#             var code = jqXHR.responseJSON && jqXHR.responseJSON.error &&
#                        jqXHR.responseJSON.error.code;
#             this.show_msg(base_message, code);
#         }
#     }
# })());
# </script>
#
#
#
#         <script>
#   (function(i,s,o,g,r,a,m){ i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-26661929-8', 'auto');
#   ga('set', 'forceSSL', true);
#   ga('send', 'pageview');
#
# </script>
#
#
#
# </head>
#
# <body class="page-master-layout page-profile">
#
#
# <div id="wrapper">
#     <header class="header">
#     <div class="background">
#
#         <div class="wrap">
#             <div class="fl">
#                                     <a href="/"><img class="logo logo-open" src="/images/site-logo" alt="" /></a>
#                                 <div class="title-wrapper">
#                     <div class="header-title">Kattis</div>
#                     <nav class="main-nav">
#                         <ul>
#
#                                 <li class=""><a href="/problems">Problems</a></li>
#
#                                 <li class=""><a href="/contests">Contests</a></li>
#
#                                 <li class="current"><a href="/ranklist">Ranklists</a></li>
#
#                                 <li class=""><a href="/jobs">Jobs</a></li>
#
#                                 <li class=""><a href="/help">Help</a></li>
#
#                                                     </ul>
#                     </nav>
#                 </div>
#             </div>
#             <div class="user-side fr">
#
#                 <nav class="user-nav">
#                     <ul class="user-nav-ul">
#                                                     <li>
#                                 <form action="/search" class="site-search" method="GET">
#                                     <input type="text" name="q" placeholder="Search Kattis" />
#                                     <a href="#">
#                                         <i class="fa fa-search"></i>
#                                     </a>
#                                 </form>
#                             </li>
#
#                                                                                     <li><a class="btn dark-bg" href="/login">Log in</a></li>
#                                                                         </ul>
#
#                 </nav>
#
#             </div>
#         </div>
#     </div>
# </header>
#
#     <!--[if IE]>    <div class="alert alert-warning" role="alert">
#         <strong>You are using an outdated browser!</strong> Some features might not look or work like expected. Kattis supports the last two versions of major browsers. Please consider upgrading to a recent version!    </div>
#     <![endif]-->
#
#
#
#
#
#
#
#
#
#
#
#     <div class="wrap">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="page-content boxed clearfix">
#     <section class="box clearfix main-content">
#         <div class="page-headline clearfix">
#             <div class="user-info clearfix">
#
#                 <div class="basic-info clearfix">
#                     <div class="university-img" style="background-image: url('/images/universities/uc.cl/160px?b68eb3e5a12144f40d24f1ff9b9e7f63');"></div>
#
#                     <div class="col-md-8">
#                         <div class="fullname row no-padding">
#                             <h1>Pontifical Catholic University of Chile</h1>
#                                                             <h4 class="ranklist-local-name">Pontificia Universidad Católica de Chile</h4>
#                                                         <div class="infobox">
#                                 <div class="country-flag">
#                                     <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                 </div>
#                             </div>
#                                                     </div>
#
#                         <div class="row">
#                                                             <div class="infobox">
#                                     <span class="title">Users</span>
#                                     <span class="header-value">52</span>
#                                 </div>
#                                                     </div>
#                     </div>
#                 </div>
#
#                                 <div class="fr score_wrapper">
#                     <div class="rank clearfix">
#                         <table>
#                             <tr>
#                                 <td><span>Rank</span></td>
#                                 <td><span>Score</span></td>
#                             </tr>
#                             <tr>
#                                 <td>162</td>
#                                 <td>129.6</td>
#                             </tr>
#                         </table>
#                     </div>
#                 </div>
#                             </div>
#
#         </div>
#     </section>
# </div>
#
# <div class="page-content boxed clearfix">
#     <section class="box clearfix main-content">
#
#         <div class="page-sub-header">
#             <h2>Top 50 users from Pontifical Catholic University of Chile</h2>
#                     </div>
#
#
#     <table class="table table-hover table-kattis">
#         <thead>
#             <tr>
#                 <th class="table-min-wrap">#</th>
#                 <th>User</th>
#                                     <th>Country</th>
#                                                 <th class="table-min-wrap">Score <span class="wrapped-link"><a href="/help/ranklist#score" aria-label="Explanation of score">?</a></span></th>
#             </tr>
#         </thead>
#         <tbody>
#
#                 <tr class="">
#                     <td>
#                                                 1
#                                             </td>
#                     <td><a href="/users/martins">Martín Muñoz Cruces</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">447.4</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 2
#                                             </td>
#                     <td><a href="/users/pabloskimg">Pablo Alfredo Messina Gallardo</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">117.1</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 3
#                                             </td>
#                     <td><a href="/users/koco">Rodrigo Gómez</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">64.1</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 4
#                                             </td>
#                     <td><a href="/users/jecastro1">Jaime Castro Retamal</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">42.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 5
#                                             </td>
#                     <td><a href="/users/luis-leiva">Luis Leiva</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">41.9</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 6
#                                             </td>
#                     <td><a href="/users/pilar-jadue">Pilar Jadue</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">27.1</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 7
#                                             </td>
#                     <td><a href="/users/francesca-lucchini">Francesca Lucchini</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">22.6</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 8
#                                             </td>
#                     <td><a href="/users/dietr1ch">Dietrich Daroch</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">18.1</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 9
#                                             </td>
#                     <td><a href="/users/banfanci">Benjamín Lobos Mayorga</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">14.1</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 10
#                                             </td>
#                     <td><a href="/users/cameneses">César Meneses</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">13.3</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 11
#                                             </td>
#                     <td><a href="/users/ignacio-castaneda">Ignacio Castañeda</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">10.8</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 12
#                                             </td>
#                     <td><a href="/users/mframos3">Matias Ramos Gomez</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">9.7</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 13
#                                             </td>
#                     <td><a href="/users/miguel-fadic">Miguel Fadić</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">9.1</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 14
#                                             </td>
#                     <td><a href="/users/lesly-reyes">Lesly Reyes</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">8.7</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 15
#                                             </td>
#                     <td><a href="/users/nacho-juan">Juan Ignacio Salas Morales</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">8.3</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 16
#                                             </td>
#                     <td><a href="/users/andres-jaque-mendez">Andres Jaque Mendez</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">8.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 17
#                                             </td>
#                     <td><a href="/users/akaske">Aurelien Kaske</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">7.9</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 18
#                                             </td>
#                     <td><a href="/users/luzho27">Luis Lillo</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">7.3</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 19
#                                             </td>
#                     <td><a href="/users/sebaburgos">Sebastián Burgos Martínez</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">6.9</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 20
#                                             </td>
#                     <td><a href="/users/mrafols">Martin Rafols</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">6.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 21
#                                             </td>
#                     <td><a href="/users/gerardo-seminario-la-torre">Gerardo Seminario La Torre</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">5.8</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 22
#                                             </td>
#                     <td><a href="/users/lucasvsj">Lucas Van Sint Jan</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">5.5</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 23
#                                             </td>
#                     <td><a href="/users/jorge-perez-facuse">Jorge Perez Facuse</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">5.4</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 24
#                                             </td>
#                     <td><a href="/users/pnicole">Paula Nicole Vergara Garrido</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">5.2</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 25
#                                             </td>
#                     <td><a href="/users/cesar.olguin">Cesar Olguin</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">5.1</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 26
#                                             </td>
#                     <td><a href="/users/benjamin-straub">Benjamin Straub</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">4.9</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 26
#                                             </td>
#                     <td><a href="/users/pablo-flores-alvarado">Pablo Flores Alvarado</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">4.9</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 28
#                                             </td>
#                     <td><a href="/users/nicolas-gomez">Nicolás Gómez</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">4.4</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 29
#                                             </td>
#                     <td><a href="/users/andres-cadiz-vidal">Andrés Cádiz Vidal</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">4.3</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 30
#                                             </td>
#                     <td><a href="/users/gabriela-guadalupe-reyes-magana">Gabriela Guadalupe Reyes Magaña</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/SLV" title="El Salvador"><img src="/images/countries/SLV/40px?5071b3940b31944fa85d8016c471374e" /></a><span class="text"><a href="/countries/SLV">El Salvador</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">3.4</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 30
#                                             </td>
#                     <td><a href="/users/miguel-angel-quintero-martinez">Miguel Angel Quintero Martinez</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">3.4</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 32
#                                             </td>
#                     <td><a href="/users/tandrighetti">Tomás Andrighetti</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">2.9</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 33
#                                             </td>
#                     <td><a href="/users/rihanuch">Rodrigo Hanuch González</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">2.6</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 34
#                                             </td>
#                     <td><a href="/users/agustin-peralta-rivas">Agustin Peralta Rivas</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">2.2</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 34
#                                             </td>
#                     <td><a href="/users/ramonmadrid">Ramón Alberto Escobar Madrid</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/SLV" title="El Salvador"><img src="/images/countries/SLV/40px?5071b3940b31944fa85d8016c471374e" /></a><span class="text"><a href="/countries/SLV">El Salvador</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">2.2</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 34
#                                             </td>
#                     <td><a href="/users/vicente-errazuriz-quiroga">Vicente Errázuriz Quiroga</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">2.2</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 37
#                                             </td>
#                     <td><a href="/users/aline-vineses">Aline Vineses</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">1.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 37
#                                             </td>
#                     <td><a href="/users/camila-hurtado">Camila Hurtado</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">1.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 37
#                                             </td>
#                     <td><a href="/users/cristianruz">Cristian Ruz</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">1.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 37
#                                             </td>
#                     <td><a href="/users/david-rolando-cornejo-arias">David Rolando Cornejo Arias</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">1.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 37
#                                             </td>
#                     <td><a href="/users/gonzalo-alonso-garcia-hoffmann">Gonzalo Alonso Garcia Hoffmann</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">1.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 37
#                                             </td>
#                     <td><a href="/users/hannah-marie-beck">Hannah-Marie Beck</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">1.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 37
#                                             </td>
#                     <td><a href="/users/maria-antonia-bulnes">Maria Antonia Bulnes</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">1.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 37
#                                             </td>
#                     <td><a href="/users/mauricio-arriagada">Mauricio Arriagada</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">1.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 37
#                                             </td>
#                     <td><a href="/users/mauricio-barrera-abarca">Mauricio Barrera Abarca</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">1.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 37
#                                             </td>
#                     <td><a href="/users/nicolas-pasten-pardo">Nicolas Pasten Pardo</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">1.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 37
#                                             </td>
#                     <td><a href="/users/nicolas-rodriguez-arnolds">Nicolas Rodriguez Arnolds</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">1.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 37
#                                             </td>
#                     <td><a href="/users/paulo-rosales">Paulo Rosales</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">1.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 37
#                                             </td>
#                     <td><a href="/users/ichottmano">Ricardo Schilling</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">1.0</td>
#                 </tr>
#
#                 <tr class="">
#                     <td>
#                                                 37
#                                             </td>
#                     <td><a href="/users/vicente-mariscal">Vicente Mariscal</a></td>
#                                             <td class="table-min-wrap">
#                                                             <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20" /></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
#                                                                                 </td>
#                                                             <td class="table-td-align-right">1.0</td>
#                 </tr>
#                                                                     </tbody>
#     </table>
#
#
#
#     <p class="last-updated-info">
#         Last updated at 01:52:04 CEST
#     </p>
#
#
#     </section>
# </div>
#
#
#     </div>
#
#
#
# </div>
#
#
# <div id="footer">
#     <div class="container">
#         <div class="row">
#             <div class="footer-info col-md-3 ">
#
#                             </div>
#             <div class="footer-powered col-md-6">
#                 <h4>
#                                       <a href="/rss/new-problems"><i class="fa fa-rss-square" style="color: orange"></i>&nbsp;RSS feed for new problems</a> |
#                                     Powered by&nbsp;Kattis                                      | <a href="https://www.patreon.com/kattis">Support Kattis on Patreon!</a>
#                                   </h4>
#             </div>
#         </div>
#     </div>
# </div>
#
#
#
#
# <script src="//cdnjs.cloudflare.com/ajax/libs/twitter-bootstrap/3.3.5/js/bootstrap.min.js"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/select2/3.4.8/select2.min.js"></script>
# <script src="//cdnjs.cloudflare.com/ajax/libs/raphael/2.1.4/raphael-min.js"></script>
# <script src="/js/system.js?66b2e0" type="text/javascript"></script>
#
#
#
#
# </body>
# </html>

# %% [markdown]
# Existen librerías de Python que nos permiten "navegar" a través de la estructura (tags) y extraer información relevante. La librería que usaremos aquí se llama "BeautifulSoup".

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(request.content, 'html.parser')

tags = soup.find_all('table')

print(tags)
# Out:
# [<table>
# <tr>
# <td><span>Rank</span></td>
# <td><span>Score</span></td>
# </tr>
# <tr>
# <td>162</td>
# <td>129.6</td>
# </tr>
# </table>, <table class="table table-hover table-kattis">
# <thead>
# <tr>
# <th class="table-min-wrap">#</th>
# <th>User</th>
# <th>Country</th>
# <th class="table-min-wrap">Score <span class="wrapped-link"><a aria-label="Explanation of score" href="/help/ranklist#score">?</a></span></th>
# </tr>
# </thead>
# <tbody>
# <tr class="">
# <td>
#                                                 1
#                                             </td>
# <td><a href="/users/martins">Martín Muñoz Cruces</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">447.4</td>
# </tr>
# <tr class="">
# <td>
#                                                 2
#                                             </td>
# <td><a href="/users/pabloskimg">Pablo Alfredo Messina Gallardo</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">117.1</td>
# </tr>
# <tr class="">
# <td>
#                                                 3
#                                             </td>
# <td><a href="/users/koco">Rodrigo Gómez</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">64.1</td>
# </tr>
# <tr class="">
# <td>
#                                                 4
#                                             </td>
# <td><a href="/users/jecastro1">Jaime Castro Retamal</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">42.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 5
#                                             </td>
# <td><a href="/users/luis-leiva">Luis Leiva</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">41.9</td>
# </tr>
# <tr class="">
# <td>
#                                                 6
#                                             </td>
# <td><a href="/users/pilar-jadue">Pilar Jadue</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">27.1</td>
# </tr>
# <tr class="">
# <td>
#                                                 7
#                                             </td>
# <td><a href="/users/francesca-lucchini">Francesca Lucchini</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">22.6</td>
# </tr>
# <tr class="">
# <td>
#                                                 8
#                                             </td>
# <td><a href="/users/dietr1ch">Dietrich Daroch</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">18.1</td>
# </tr>
# <tr class="">
# <td>
#                                                 9
#                                             </td>
# <td><a href="/users/banfanci">Benjamín Lobos Mayorga</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">14.1</td>
# </tr>
# <tr class="">
# <td>
#                                                 10
#                                             </td>
# <td><a href="/users/cameneses">César Meneses</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">13.3</td>
# </tr>
# <tr class="">
# <td>
#                                                 11
#                                             </td>
# <td><a href="/users/ignacio-castaneda">Ignacio Castañeda</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">10.8</td>
# </tr>
# <tr class="">
# <td>
#                                                 12
#                                             </td>
# <td><a href="/users/mframos3">Matias Ramos Gomez</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">9.7</td>
# </tr>
# <tr class="">
# <td>
#                                                 13
#                                             </td>
# <td><a href="/users/miguel-fadic">Miguel Fadić</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">9.1</td>
# </tr>
# <tr class="">
# <td>
#                                                 14
#                                             </td>
# <td><a href="/users/lesly-reyes">Lesly Reyes</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">8.7</td>
# </tr>
# <tr class="">
# <td>
#                                                 15
#                                             </td>
# <td><a href="/users/nacho-juan">Juan Ignacio Salas Morales</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">8.3</td>
# </tr>
# <tr class="">
# <td>
#                                                 16
#                                             </td>
# <td><a href="/users/andres-jaque-mendez">Andres Jaque Mendez</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">8.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 17
#                                             </td>
# <td><a href="/users/akaske">Aurelien Kaske</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">7.9</td>
# </tr>
# <tr class="">
# <td>
#                                                 18
#                                             </td>
# <td><a href="/users/luzho27">Luis Lillo</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">7.3</td>
# </tr>
# <tr class="">
# <td>
#                                                 19
#                                             </td>
# <td><a href="/users/sebaburgos">Sebastián Burgos Martínez</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">6.9</td>
# </tr>
# <tr class="">
# <td>
#                                                 20
#                                             </td>
# <td><a href="/users/mrafols">Martin Rafols</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">6.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 21
#                                             </td>
# <td><a href="/users/gerardo-seminario-la-torre">Gerardo Seminario La Torre</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">5.8</td>
# </tr>
# <tr class="">
# <td>
#                                                 22
#                                             </td>
# <td><a href="/users/lucasvsj">Lucas Van Sint Jan</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">5.5</td>
# </tr>
# <tr class="">
# <td>
#                                                 23
#                                             </td>
# <td><a href="/users/jorge-perez-facuse">Jorge Perez Facuse</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">5.4</td>
# </tr>
# <tr class="">
# <td>
#                                                 24
#                                             </td>
# <td><a href="/users/pnicole">Paula Nicole Vergara Garrido</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">5.2</td>
# </tr>
# <tr class="">
# <td>
#                                                 25
#                                             </td>
# <td><a href="/users/cesar.olguin">Cesar Olguin</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">5.1</td>
# </tr>
# <tr class="">
# <td>
#                                                 26
#                                             </td>
# <td><a href="/users/benjamin-straub">Benjamin Straub</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">4.9</td>
# </tr>
# <tr class="">
# <td>
#                                                 26
#                                             </td>
# <td><a href="/users/pablo-flores-alvarado">Pablo Flores Alvarado</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">4.9</td>
# </tr>
# <tr class="">
# <td>
#                                                 28
#                                             </td>
# <td><a href="/users/nicolas-gomez">Nicolás Gómez</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">4.4</td>
# </tr>
# <tr class="">
# <td>
#                                                 29
#                                             </td>
# <td><a href="/users/andres-cadiz-vidal">Andrés Cádiz Vidal</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">4.3</td>
# </tr>
# <tr class="">
# <td>
#                                                 30
#                                             </td>
# <td><a href="/users/gabriela-guadalupe-reyes-magana">Gabriela Guadalupe Reyes Magaña</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/SLV" title="El Salvador"><img src="/images/countries/SLV/40px?5071b3940b31944fa85d8016c471374e"/></a><span class="text"><a href="/countries/SLV">El Salvador</a></span></div>
# </td>
# <td class="table-td-align-right">3.4</td>
# </tr>
# <tr class="">
# <td>
#                                                 30
#                                             </td>
# <td><a href="/users/miguel-angel-quintero-martinez">Miguel Angel Quintero Martinez</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">3.4</td>
# </tr>
# <tr class="">
# <td>
#                                                 32
#                                             </td>
# <td><a href="/users/tandrighetti">Tomás Andrighetti</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">2.9</td>
# </tr>
# <tr class="">
# <td>
#                                                 33
#                                             </td>
# <td><a href="/users/rihanuch">Rodrigo Hanuch González</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">2.6</td>
# </tr>
# <tr class="">
# <td>
#                                                 34
#                                             </td>
# <td><a href="/users/agustin-peralta-rivas">Agustin Peralta Rivas</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">2.2</td>
# </tr>
# <tr class="">
# <td>
#                                                 34
#                                             </td>
# <td><a href="/users/ramonmadrid">Ramón Alberto Escobar Madrid</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/SLV" title="El Salvador"><img src="/images/countries/SLV/40px?5071b3940b31944fa85d8016c471374e"/></a><span class="text"><a href="/countries/SLV">El Salvador</a></span></div>
# </td>
# <td class="table-td-align-right">2.2</td>
# </tr>
# <tr class="">
# <td>
#                                                 34
#                                             </td>
# <td><a href="/users/vicente-errazuriz-quiroga">Vicente Errázuriz Quiroga</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">2.2</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/aline-vineses">Aline Vineses</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/camila-hurtado">Camila Hurtado</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/cristianruz">Cristian Ruz</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/david-rolando-cornejo-arias">David Rolando Cornejo Arias</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/gonzalo-alonso-garcia-hoffmann">Gonzalo Alonso Garcia Hoffmann</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/hannah-marie-beck">Hannah-Marie Beck</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/maria-antonia-bulnes">Maria Antonia Bulnes</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/mauricio-arriagada">Mauricio Arriagada</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/mauricio-barrera-abarca">Mauricio Barrera Abarca</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/nicolas-pasten-pardo">Nicolas Pasten Pardo</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/nicolas-rodriguez-arnolds">Nicolas Rodriguez Arnolds</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/paulo-rosales">Paulo Rosales</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/ichottmano">Ricardo Schilling</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/vicente-mariscal">Vicente Mariscal</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# </tbody>
# </table>]

# %%
score_table = tags[1]

print(score_table)
# Out:
# <table class="table table-hover table-kattis">
# <thead>
# <tr>
# <th class="table-min-wrap">#</th>
# <th>User</th>
# <th>Country</th>
# <th class="table-min-wrap">Score <span class="wrapped-link"><a aria-label="Explanation of score" href="/help/ranklist#score">?</a></span></th>
# </tr>
# </thead>
# <tbody>
# <tr class="">
# <td>
#                                                 1
#                                             </td>
# <td><a href="/users/martins">Martín Muñoz Cruces</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">447.4</td>
# </tr>
# <tr class="">
# <td>
#                                                 2
#                                             </td>
# <td><a href="/users/pabloskimg">Pablo Alfredo Messina Gallardo</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">117.1</td>
# </tr>
# <tr class="">
# <td>
#                                                 3
#                                             </td>
# <td><a href="/users/koco">Rodrigo Gómez</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">64.1</td>
# </tr>
# <tr class="">
# <td>
#                                                 4
#                                             </td>
# <td><a href="/users/jecastro1">Jaime Castro Retamal</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">42.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 5
#                                             </td>
# <td><a href="/users/luis-leiva">Luis Leiva</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">41.9</td>
# </tr>
# <tr class="">
# <td>
#                                                 6
#                                             </td>
# <td><a href="/users/pilar-jadue">Pilar Jadue</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">27.1</td>
# </tr>
# <tr class="">
# <td>
#                                                 7
#                                             </td>
# <td><a href="/users/francesca-lucchini">Francesca Lucchini</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">22.6</td>
# </tr>
# <tr class="">
# <td>
#                                                 8
#                                             </td>
# <td><a href="/users/dietr1ch">Dietrich Daroch</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">18.1</td>
# </tr>
# <tr class="">
# <td>
#                                                 9
#                                             </td>
# <td><a href="/users/banfanci">Benjamín Lobos Mayorga</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">14.1</td>
# </tr>
# <tr class="">
# <td>
#                                                 10
#                                             </td>
# <td><a href="/users/cameneses">César Meneses</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">13.3</td>
# </tr>
# <tr class="">
# <td>
#                                                 11
#                                             </td>
# <td><a href="/users/ignacio-castaneda">Ignacio Castañeda</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">10.8</td>
# </tr>
# <tr class="">
# <td>
#                                                 12
#                                             </td>
# <td><a href="/users/mframos3">Matias Ramos Gomez</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">9.7</td>
# </tr>
# <tr class="">
# <td>
#                                                 13
#                                             </td>
# <td><a href="/users/miguel-fadic">Miguel Fadić</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">9.1</td>
# </tr>
# <tr class="">
# <td>
#                                                 14
#                                             </td>
# <td><a href="/users/lesly-reyes">Lesly Reyes</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">8.7</td>
# </tr>
# <tr class="">
# <td>
#                                                 15
#                                             </td>
# <td><a href="/users/nacho-juan">Juan Ignacio Salas Morales</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">8.3</td>
# </tr>
# <tr class="">
# <td>
#                                                 16
#                                             </td>
# <td><a href="/users/andres-jaque-mendez">Andres Jaque Mendez</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">8.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 17
#                                             </td>
# <td><a href="/users/akaske">Aurelien Kaske</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">7.9</td>
# </tr>
# <tr class="">
# <td>
#                                                 18
#                                             </td>
# <td><a href="/users/luzho27">Luis Lillo</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">7.3</td>
# </tr>
# <tr class="">
# <td>
#                                                 19
#                                             </td>
# <td><a href="/users/sebaburgos">Sebastián Burgos Martínez</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">6.9</td>
# </tr>
# <tr class="">
# <td>
#                                                 20
#                                             </td>
# <td><a href="/users/mrafols">Martin Rafols</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">6.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 21
#                                             </td>
# <td><a href="/users/gerardo-seminario-la-torre">Gerardo Seminario La Torre</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">5.8</td>
# </tr>
# <tr class="">
# <td>
#                                                 22
#                                             </td>
# <td><a href="/users/lucasvsj">Lucas Van Sint Jan</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">5.5</td>
# </tr>
# <tr class="">
# <td>
#                                                 23
#                                             </td>
# <td><a href="/users/jorge-perez-facuse">Jorge Perez Facuse</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">5.4</td>
# </tr>
# <tr class="">
# <td>
#                                                 24
#                                             </td>
# <td><a href="/users/pnicole">Paula Nicole Vergara Garrido</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">5.2</td>
# </tr>
# <tr class="">
# <td>
#                                                 25
#                                             </td>
# <td><a href="/users/cesar.olguin">Cesar Olguin</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">5.1</td>
# </tr>
# <tr class="">
# <td>
#                                                 26
#                                             </td>
# <td><a href="/users/benjamin-straub">Benjamin Straub</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">4.9</td>
# </tr>
# <tr class="">
# <td>
#                                                 26
#                                             </td>
# <td><a href="/users/pablo-flores-alvarado">Pablo Flores Alvarado</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">4.9</td>
# </tr>
# <tr class="">
# <td>
#                                                 28
#                                             </td>
# <td><a href="/users/nicolas-gomez">Nicolás Gómez</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">4.4</td>
# </tr>
# <tr class="">
# <td>
#                                                 29
#                                             </td>
# <td><a href="/users/andres-cadiz-vidal">Andrés Cádiz Vidal</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">4.3</td>
# </tr>
# <tr class="">
# <td>
#                                                 30
#                                             </td>
# <td><a href="/users/gabriela-guadalupe-reyes-magana">Gabriela Guadalupe Reyes Magaña</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/SLV" title="El Salvador"><img src="/images/countries/SLV/40px?5071b3940b31944fa85d8016c471374e"/></a><span class="text"><a href="/countries/SLV">El Salvador</a></span></div>
# </td>
# <td class="table-td-align-right">3.4</td>
# </tr>
# <tr class="">
# <td>
#                                                 30
#                                             </td>
# <td><a href="/users/miguel-angel-quintero-martinez">Miguel Angel Quintero Martinez</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">3.4</td>
# </tr>
# <tr class="">
# <td>
#                                                 32
#                                             </td>
# <td><a href="/users/tandrighetti">Tomás Andrighetti</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">2.9</td>
# </tr>
# <tr class="">
# <td>
#                                                 33
#                                             </td>
# <td><a href="/users/rihanuch">Rodrigo Hanuch González</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">2.6</td>
# </tr>
# <tr class="">
# <td>
#                                                 34
#                                             </td>
# <td><a href="/users/agustin-peralta-rivas">Agustin Peralta Rivas</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">2.2</td>
# </tr>
# <tr class="">
# <td>
#                                                 34
#                                             </td>
# <td><a href="/users/ramonmadrid">Ramón Alberto Escobar Madrid</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/SLV" title="El Salvador"><img src="/images/countries/SLV/40px?5071b3940b31944fa85d8016c471374e"/></a><span class="text"><a href="/countries/SLV">El Salvador</a></span></div>
# </td>
# <td class="table-td-align-right">2.2</td>
# </tr>
# <tr class="">
# <td>
#                                                 34
#                                             </td>
# <td><a href="/users/vicente-errazuriz-quiroga">Vicente Errázuriz Quiroga</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">2.2</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/aline-vineses">Aline Vineses</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/camila-hurtado">Camila Hurtado</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/cristianruz">Cristian Ruz</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/david-rolando-cornejo-arias">David Rolando Cornejo Arias</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/gonzalo-alonso-garcia-hoffmann">Gonzalo Alonso Garcia Hoffmann</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/hannah-marie-beck">Hannah-Marie Beck</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/maria-antonia-bulnes">Maria Antonia Bulnes</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/mauricio-arriagada">Mauricio Arriagada</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/mauricio-barrera-abarca">Mauricio Barrera Abarca</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/nicolas-pasten-pardo">Nicolas Pasten Pardo</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/nicolas-rodriguez-arnolds">Nicolas Rodriguez Arnolds</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/paulo-rosales">Paulo Rosales</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/ichottmano">Ricardo Schilling</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# <tr class="">
# <td>
#                                                 37
#                                             </td>
# <td><a href="/users/vicente-mariscal">Vicente Mariscal</a></td>
# <td class="table-min-wrap">
# <div class="country-flag has_flag"><a href="/countries/CHL" title="Chile"><img src="/images/countries/CHL/40px?e3bcbe8bc7c9f199da895db8e5f03f20"/></a><span class="text"><a href="/countries/CHL">Chile</a></span></div>
# </td>
# <td class="table-td-align-right">1.0</td>
# </tr>
# </tbody>
# </table>

# %%
#cargo lista de usuarios a buscar
with open('usuarios_kattis.txt', 'r', encoding='utf-8-sig') as archivo:
    alumnos = [line.strip() for line in archivo]

print('Lista de usuarios a buscar:')
print(alumnos)
print()

#selecciono las filas de la tabla
row_tags = score_table.select('tr')
print('Hay {} filas en la tabla'.format(len(row_tags)))
# Out:
# Lista de usuarios a buscar:
# ['Martin Rafols', 'Gerardo Seminario La Torre', 'Aurelien Kaske', 'Miguel Angel Quintero Martinez', 'Gabriela Guadalupe Reyes Magaña', 'Ramón Alberto Escobar Madrid', 'Aline Vineses', 'Camila Hurtado', 'David Rolando Cornejo Arias', 'Gonzalo Alonso Garcia Hoffmann', 'Maria Antonia Bulnes', 'Mauricio Aburto', 'Nicolas Pasten Pardo', 'Nicolas Rodriguez Arnolds', 'Paulo Rosales']
#
# Hay 51 filas en la tabla

# %%
print('Descargando datos de la tabla:...')
print()

rows_out = []

#extraigo información fila por fila
for row in row_tags:
    
    #selecciono las columnas de esa fila
    col_tags = row.select('td')
    
    #extraigo el texto de cada "celda"
    aux_row = [celda.get_text().strip() for celda in col_tags]
    
    #si hay información, la guardo
    if aux_row:
        rows_out.append(aux_row)

for row in rows_out:
    print(row)
# Out:
# Descargando datos de la tabla:...
#
# ['1', 'Martín Muñoz Cruces', 'Chile', '447.4']
# ['2', 'Pablo Alfredo Messina Gallardo', 'Chile', '117.1']
# ['3', 'Rodrigo Gómez', 'Chile', '64.1']
# ['4', 'Jaime Castro Retamal', 'Chile', '42.0']
# ['5', 'Luis Leiva', 'Chile', '41.9']
# ['6', 'Pilar Jadue', 'Chile', '27.1']
# ['7', 'Francesca Lucchini', 'Chile', '22.6']
# ['8', 'Dietrich Daroch', 'Chile', '18.1']
# ['9', 'Benjamín Lobos Mayorga', 'Chile', '14.1']
# ['10', 'César Meneses', 'Chile', '13.3']
# ['11', 'Ignacio Castañeda', 'Chile', '10.8']
# ['12', 'Matias Ramos Gomez', 'Chile', '9.7']
# ['13', 'Miguel Fadić', 'Chile', '9.1']
# ['14', 'Lesly Reyes', 'Chile', '8.7']
# ['15', 'Juan Ignacio Salas Morales', 'Chile', '8.3']
# ['16', 'Andres Jaque Mendez', 'Chile', '8.0']
# ['17', 'Aurelien Kaske', 'Chile', '7.9']
# ['18', 'Luis Lillo', 'Chile', '7.3']
# ['19', 'Sebastián Burgos Martínez', 'Chile', '6.9']
# ['20', 'Martin Rafols', 'Chile', '6.0']
# ['21', 'Gerardo Seminario La Torre', 'Chile', '5.8']
# ['22', 'Lucas Van Sint Jan', 'Chile', '5.5']
# ['23', 'Jorge Perez Facuse', 'Chile', '5.4']
# ['24', 'Paula Nicole Vergara Garrido', 'Chile', '5.2']
# ['25', 'Cesar Olguin', 'Chile', '5.1']
# ['26', 'Benjamin Straub', 'Chile', '4.9']
# ['26', 'Pablo Flores Alvarado', 'Chile', '4.9']
# ['28', 'Nicolás Gómez', 'Chile', '4.4']
# ['29', 'Andrés Cádiz Vidal', 'Chile', '4.3']
# ['30', 'Gabriela Guadalupe Reyes Magaña', 'El Salvador', '3.4']
# ['30', 'Miguel Angel Quintero Martinez', 'Chile', '3.4']
# ['32', 'Tomás Andrighetti', 'Chile', '2.9']
# ['33', 'Rodrigo Hanuch González', 'Chile', '2.6']
# ['34', 'Agustin Peralta Rivas', 'Chile', '2.2']
# ['34', 'Ramón Alberto Escobar Madrid', 'El Salvador', '2.2']
# ['34', 'Vicente Errázuriz Quiroga', 'Chile', '2.2']
# ['37', 'Aline Vineses', 'Chile', '1.0']
# ['37', 'Camila Hurtado', 'Chile', '1.0']
# ['37', 'Cristian Ruz', 'Chile', '1.0']
# ['37', 'David Rolando Cornejo Arias', 'Chile', '1.0']
# ['37', 'Gonzalo Alonso Garcia Hoffmann', 'Chile', '1.0']
# ['37', 'Hannah-Marie Beck', 'Chile', '1.0']
# ['37', 'Maria Antonia Bulnes', 'Chile', '1.0']
# ['37', 'Mauricio Arriagada', 'Chile', '1.0']
# ['37', 'Mauricio Barrera Abarca', 'Chile', '1.0']
# ['37', 'Nicolas Pasten Pardo', 'Chile', '1.0']
# ['37', 'Nicolas Rodriguez Arnolds', 'Chile', '1.0']
# ['37', 'Paulo Rosales', 'Chile', '1.0']
# ['37', 'Ricardo Schilling', 'Chile', '1.0']
# ['37', 'Vicente Mariscal', 'Chile', '1.0']

# %%
#extraigo información relevante de los usuarios que me interesan
for num, nombre, pais, puntaje in rows_out:
    if nombre in alumnos:
        print((num, nombre, pais, puntaje))
# Out:
# ('17', 'Aurelien Kaske', 'Chile', '7.9')
# ('20', 'Martin Rafols', 'Chile', '6.0')
# ('21', 'Gerardo Seminario La Torre', 'Chile', '5.8')
# ('30', 'Gabriela Guadalupe Reyes Magaña', 'El Salvador', '3.4')
# ('30', 'Miguel Angel Quintero Martinez', 'Chile', '3.4')
# ('34', 'Ramón Alberto Escobar Madrid', 'El Salvador', '2.2')
# ('37', 'Aline Vineses', 'Chile', '1.0')
# ('37', 'Camila Hurtado', 'Chile', '1.0')
# ('37', 'David Rolando Cornejo Arias', 'Chile', '1.0')
# ('37', 'Gonzalo Alonso Garcia Hoffmann', 'Chile', '1.0')
# ('37', 'Maria Antonia Bulnes', 'Chile', '1.0')
# ('37', 'Nicolas Pasten Pardo', 'Chile', '1.0')
# ('37', 'Nicolas Rodriguez Arnolds', 'Chile', '1.0')
# ('37', 'Paulo Rosales', 'Chile', '1.0')

# %% [markdown]
# #### Ejemplo 2. Búsqueda información "I'm feeling lucky"

# %%
import requests

base_url = 'http://www.google.com/search?q={}&btnI'

terminos_a_buscar = ['paulo', 'rosales']

url = base_url.format('+'.join(terminos_a_buscar))

print(url)

request = requests.get(url)
# Out:
# http://www.google.com/search?q=paulo+rosales&btnI

# %%
soup = BeautifulSoup(request.content, 'html.parser')

print(soup.get_text())
# Out:
# Paulo Rosales - Wikipedia, la enciclopedia libre
# document.documentElement.className = document.documentElement.className.replace( /(^|\s)client-nojs(\s|$)/, "$1client-js$2" );
# (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Paulo_Rosales","wgTitle":"Paulo Rosales","wgCurRevisionId":107945742,"wgRevisionId":107945742,"wgArticleId":1497808,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:Artículos con datos por trasladar a Wikidata","Wikipedia:Mantenimiento de la plantilla Altura (metro)","Personas vivas","Nacidos en 1984","Hombres","Coscoínos","Futbolistas de la provincia de Córdoba (Argentina)","Futbolistas del Club Atlético Newell's Old Boys","Futbolistas del Club Atlético Unión (Santa Fe)","Futbolistas del Club Atlético Talleres (Córdoba)","Futbolistas del Olympiakos Volou","Futbolistas del Club Atlético Independiente","Futbolistas del Esporte Clube Bahia","Futbolistas del Club Olimpo","Futbolistas del Club de Deportes Unión La Calera en los años 2010","Futbolistas del Club de Deportes Santiago Wanderers en los años 2010"],"wgBreakFrames":false,"wgPageContentLanguage":"es","wgPageContentModel":"wikitext","wgSeparatorTransformTable":[",\t."," \t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgMonthNamesShort":["","ene","feb","mar","abr","may","jun","jul","ago","sep","oct","nov","dic"],"wgRelevantPageName":"Paulo_Rosales","wgRelevantArticleId":1497808,"wgRequestId":"W4cfuApAMEwAAIRgtXIAAABY","wgCSPNonce":false,"wgIsProbablyEditable":true,"wgRelevantPageIsProbablyEditable":true,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgCategoryTreePageCategoryOptions":"{\"mode\":0,\"hideprefix\":20,\"showcount\":true,\"namespaces\":false}","wgWikiEditorEnabledModules":[],"wgBetaFeaturesFeatures":[],"wgMediaViewerOnClick":true,"wgMediaViewerEnabledByDefault":true,"wgPopupsShouldSendModuleToUser":true,"wgPopupsConflictsWithNavPopupGadget":false,"wgVisualEditor":{"pageLanguageCode":"es","pageLanguageDir":"ltr","pageVariantFallbacks":"es","usePageImages":true,"usePageDescriptions":true},"wgMFExpandAllSectionsUserOption":true,"wgMFEnableFontChanger":true,"wgMFDisplayWikibaseDescriptions":{"search":true,"nearby":true,"watchlist":true,"tagline":true},"wgRelatedArticles":null,"wgRelatedArticlesUseCirrusSearch":true,"wgRelatedArticlesOnlyUseCirrusSearch":false,"wgULSCurrentAutonym":"español","wgNoticeProject":"wikipedia","wgCentralNoticeCookiesToDelete":[],"wgCentralNoticeCategoriesUsingLegacy":["Fundraising","fundraising"],"wgWikibaseItemId":"Q10346803","wgScoreNoteLanguages":{"arabic":"العربية","catalan":"català","deutsch":"Deutsch","english":"English","espanol":"español","italiano":"italiano","nederlands":"Nederlands","norsk":"norsk","portugues":"português","suomi":"suomi","svenska":"svenska","vlaams":"West-Vlams"},"wgScoreDefaultNoteLanguage":"nederlands","wgCentralAuthMobileDomain":false,"wgCodeMirrorEnabled":true,"wgVisualEditorToolbarScrollOffset":0,"wgVisualEditorUnsupportedEditParams":["undo","undoafter","veswitched"],"wgEditSubmitButtonLabelPublish":true});mw.loader.state({"ext.gadget.imagenesinfobox":"ready","ext.globalCssJs.user.styles":"ready","ext.globalCssJs.site.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","ext.globalCssJs.site":"ready","user":"ready","user.options":"loading","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","mediawiki.toc.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","mediawiki.skinning.interface":"ready","skins.vector.styles":"ready"});mw.loader.implement("user.options@00wq302",function($,jQuery,require,module){/*@nomin*/mw.user.options.set({"variant":"es"});
# });mw.loader.implement("user.tokens@1dqfd7l",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"editToken":"+\\","patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });mw.loader.load(["ext.cite.a11y","site","mediawiki.page.startup","mediawiki.user","mediawiki.page.ready","mediawiki.toc","mediawiki.searchSuggest","ext.gadget.a-commons-directo","ext.gadget.refToolbar","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging.subscriber","ext.wikimediaEvents","ext.navigationTiming","ext.uls.eventlogger","ext.uls.init","ext.uls.compactlinks","ext.uls.interface","ext.3d","ext.centralNotice.geoIP","ext.centralNotice.startUp","skins.vector.js"]);});
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Paulo Rosales
# De Wikipedia, la enciclopedia libre
#  Ir a la navegación
# Ir a la búsqueda
# Paulo Rosales
# Paulo durante un partido del Santiago Wanderers.Datos personalesNombre completo
# Paulo Roberto Rosales AltamiranoApodo(s)
# PichiNacimiento
# Cosquín, Córdoba10 de enero de 1984 (34 años)Nacionalidad(es)
# Altura
# 1,68 m (5 ft 6 in)Peso
# 63 kg (139 lb)CarreraDeporte
# FútbolDebut deportivo
# 2002(Newell's Old Boys)Club
# Oriente PetroleroLiga
# Primera División de BoliviaPosición
# Mediocampista[editar datos en Wikidata]
# Paulo Roberto Rosales Altamirano (Cosquín, Provincia de Córdoba, Argentina, 10 de enero de 1984) es un futbolista argentino. Juega de mediocampista y su actual equipo es Oriente Petrolero de la Primera División de Bolivia.
# Jugó en Newell's Old Boys con Mauro Rosales, ambos de edad cercana, pero sin ningún parentesco, a pesar de que la gente suele confundirse en este tema.[1]​
#
# Índice
#
# 1 Trayectoria
#
# 1.1 Newell's Old Boys
# 1.2 Independiente
#
#
# 2 Selección nacional
# 3 Estadísticas
#
# 3.1 Clubes
#
#
# 4 Títulos
#
# 4.1 Nacionales
#
#
# 5 Referencias
#
#
# Trayectoria[editar]
# Newell's Old Boys[editar]
# Paulo Rosales debutó en Newell's Old Boys en 2002, siendo una gran promesa para los Leprosos. Jugó al lado de Fernando Belluschi, Ignacio Scocco, Justo Villar, Ezequiel Garay, Ariel Ortega. En el equipo rosarino permaneció hasta 2005, hasta que fue transferido a Unión de Santa Fe.
# En Unión de Santa Fe jugó dos temporadas en la Primera "B" Nacional. A mitad de la temporada 2007/2008 forma parte del plantel de Talleres de Córdoba, a préstamo por 6 meses. Luego de su paso por la entidad cordobesa, cerca de un segundo préstamo, optó por retornar al equipo Santafesino.
# A principios de 2009 es cedido a préstamo al Olympiakos Volou de Grecia, con una opción de compra. Debido a una crisis financiera por la cual transcurría dicho país europeo, Rosales decide por cuenta propia retornar al equipo Tatengue. En 2011 logra el ascenso con Unión de Santa Fe a la Primera División, siendo una de las piezas claves del equipo de Frank Darío Kudelka.
# Para la temporada 2011/2012 en la Primera División le fue asignado el dorsal número 10, teniendo una gran actuación en el Apertura 2011, convirtiéndose así en el mejor jugador, goleador del plantel y uno de los mejores jugadores del torneo. Finalizado el Clausura 2012, vence su vínculo con Unión y al no llegar a un acuerdo con la dirigencia Santafesina, queda libre con el pase en su poder.[2]​
#
# Independiente[editar]
# 6 de julio de 2012 recibe un llamado de Javier Cantero, el presidente del Club Atlético Independiente, quien le ofrece contratarlo como el nuevo enganche del equipo de Avellaneda, y revelándole que había sido elegido a dedo por el mismísimo Ricardo Enrique Bochini, ídolo histórico del Rojo que supo llevar la N°10 en su espalda ganando títulos alrededor del mundo.[3]​ De esta forma el martes 10 de julio de 2012 firmaría un contrato con el club de Avellaneda por dos años, con opción de extenderlo por un año más, y se convirtió en el primer refuerzo del Rojo en la pretemporada, siéndole asignado el N°20 de la camiseta.[4]​ Marcó su primer gol con la institución Roja en el partido de ida de la Sudamericana frente a Boca el cual sería empate 3-3 en la Bombonera, marcando el 2-2 parcial con un remate de afuera del área ante un arquero descolocado.[5]​ Por la fecha 9 del Campeonato de Primera División, Club Atlético Independiente, jugaba contra Unión en el Estadio 15 de Abril, ambos equipos buscando su primera victoria en el Campeonato, la cual se terminarían llevando los Rojos por 2-1, con un doblete del "Tecla" Farías,[6]​ donde le tocó ingresar a los 10 del segundo tiempo por su compañero Luciano Leguizamón.[7]​
# En julio de 2013, cierra su fichaje con el Club Olimpo de Bahía Blanca, recientemente ascendido a la primera división del Fútbol Argentino, donde solo permanecería seis meses para luego ir a Chile, para jugar por Unión La Calera de la Primera División. En el cuadro cementero tendría un buen rendimiento tomando los hilos del mediocampo, destacando en el Clausura 2015 con una campaña donde llevaría a su equipo a jugar la liguilla por un cupo a la Copa Sudamericana y a su compañero, Jean Paul Pineda, a ser goleador del torneo, tras esto, Universidad Católica y Santiago Wanderers estarían tras él, llegando al segundo club mencionado como remplazo de Jorge Luna.
# A inicios del 2018 llega a Oriente Petrolero para jugar la Copa Libertadores 2018 y el torneo local. Llega en reemplazo de su compatriota Damian Lizio.
#
# Selección nacional[editar]
# Ha sido parte de la Selección de fútbol sub-15 de Argentina disputando torneos amistosos y la misma selección a nivel Sub-17 con la que disputó el Campeonato Sudamericano Sub-17 de 2001 con grandes figuras como Carlos Tévez o Javier Mascherano, obteniendo el segundo lugar de dicho campeonato, lo que le valió la clasificación al mundial de la categoría donde no sería tomado en cuenta.[8]​
#
# Estadísticas[editar]
# Clubes[editar]
#  Actualizado al último partido jugado el 16 de octubre de 2017.
#
#
# Club
#
# Div
#
# Temporada
#
# Liga
#
# Copasnacionales(1)
#
# Torneosinternacionales(2)
#
# Total
#
#
# Part.
#
# Goles
#
# Asist.
#
# Part.
#
# Goles
#
# Asist.
#
# Part.
#
# Goles
#
# Asist.
#
# Part.
#
# Goles
#
# Asist.
#
#
# Newell's Old BoysArgentina Argentina
#
#
# 1ª
#
# 2002-A
# 1
# 0
# 0
# --
# --
# --
# --
# --
# --
#
# 1
#
# 0
#
# 0
#
#
# 2003-C
# 5
# 0
# 0
# --
# --
# --
# --
# --
# --
#
# 5
#
# 0
#
# 0
#
#
# 2003-A
# 14
# 0
#
# --
# --
# --
# --
# --
# --
#
# 14
#
# 0
#
#
#
#
# 2004-C
# --
# --
# --
# --
# --
# --
# --
# --
# --
#
# --
#
# --
#
# --
#
#
# 2004-A
# --
# --
# --
# --
# --
# --
# --
# --
# --
#
# --
#
# --
#
# --
#
#
# 2005-C
# 2
# 0
# 0
# --
# --
# --
# --
# --
# --
#
# 2
#
# 0
#
# 0
#
#
# Total club
# 22
# 0
# 0
# --
# --
# --
# --
# --
# --
# 22
# 0
# 0
#
#
# Unión de Santa FeArgentina Argentina
#
#
# 2ª
#
# 2005/2006
# 32
# 5
#
# --
# --
# --
# --
# --
# --
#
# 32
#
# 5
#
#
#
#
# 2006/2007
# 37
# 11
#
# --
# --
# --
# --
# --
# --
#
# 37
#
# 11
#
#
#
#
# 2007/2008
# 16
# 2
#
# --
# --
# --
# --
# --
# --
#
# 16
#
# 2
#
#
#
#
# 2008/2009
# 13
# 3
#
# --
# --
# --
# --
# --
# --
#
# 13
#
# 3
#
#
#
#
# 2009/2010
# 11
# 0
# 1
# --
# --
# --
# --
# --
# --
#
# 11
#
# 0
#
# 1
#
#
# 2010/2011
# 37
# 7
# 4
# --
# --
# --
# --
# --
# --
#
# 37
#
# 7
#
# 4
#
#
# 1ª
#
# 2011-A
# 18
# 5
# 2
# --
# --
# --
# --
# --
# --
#
# 18
#
# 5
#
# 2
#
#
# 2012-C
# 17
# 0
# 5
# --
# --
# --
# --
# --
# --
#
# 17
#
# 0
#
# 5
#
#
# Total club
# 181
# 33
# 12
# --
# --
# --
# --
# --
# --
# 181
# 33
# 12
#
#
# Talleres de CórdobaArgentina Argentina
#
#
# 2ª
#
# 2007/2008
# 20
# 6
#
# --
# --
# --
# --
# --
# --
#
# 20
#
# 6
#
#
#
#
# Total club
# 20
# 6
#
# --
# --
# --
# --
# --
# --
# 20
# 6
#
#
#
# Olympiakos VolouGrecia Grecia
#
#
# 2ª
#
# 2008/2009
# 7
# 2
# 0
# --
# --
# --
# --
# --
# --
#
# 7
#
# 2
#
# 0
#
#
# Total club
# 7
# 2
# 0
# --
# --
# --
# --
# --
# --
# 7
# 2
# 0
#
#
# IndependienteArgentina Argentina
#
#
# 1ª
#
# 2012-A
# 15
# 0
# 0
# --
# --
# --
# 6
# 2
# 0
#
# 21
#
# 2
#
# 0
#
#
# Total club
# 15
# 0
# 0
# --
# --
# --
# 6
# 2
# 0
# 21
# 2
# 0
#
#
# BahiaBrasil Brasil
#
#
# 1ª
#
# 2013
# 8
# 0
#
# 2
# 0
#
# --
# --
# --
#
# 10
#
# 0
#
#
#
#
# Total club
# 8
# 0
#
# 2
# 0
#
# --
# --
# --
# 10
# 0
#
#
#
# OlimpoArgentina Argentina
#
#
# 1ª
#
# 2013-A
# 17
# 1
# 1
# --
# --
# --
# --
# --
# --
#
# 17
#
# 1
#
# 1
#
#
# Total club
# 17
# 1
# 1
# --
# --
# --
# --
# --
# --
# 17
# 1
# 1
#
#
# Unión La CaleraChile Chile
#
#
# 1ª
#
# 2014-C
# 13
# 3
#
# --
# --
# --
# --
# --
# --
#
# 13
#
# 3
#
#
#
#
# 2014-A
# 16
# 1
# 3
# 6
# 1
#
# --
# --
# --
#
# 22
#
# 2
#
# 3
#
#
# 2015-C
# 19
# 5
# 8
# --
# --
# --
# --
# --
# --
#
# 19
#
# 5
#
# 8
#
#
# Total club
# 48
# 9
# 11
# 6
# 1
#
# --
# --
# --
# 54
# 10
# 11
#
#
# Santiago WanderersChile Chile
#
#
# 1ª
#
# 2015-A
# 13
# 1
# 4
# 6
# 0
#
# 2
# 0
# 0
#
# 21
#
# 1
#
# 4
#
#
# 2016-C
# 10
# 2
# 0
# --
# --
# --
# --
# --
# --
#
# 10
#
# 2
#
# 0
#
#
# Total club
# 23
# 3
# 4
# 6
# 0
# 0
# 2
# 0
# 0
# 31
# 3
# 4
#
#
# InstitutoArgentina Argentina
#
#
# 2ª
#
# 2016/2017
# 38
# 7
# 9
# 1
# 1
# 0
# --
# --
# --
#
# 39
#
# 8
#
# 9
#
#
# Total club
# 38
# 7
# 9
# 1
# 1
# 0
# --
# --
# --
# 39
# 8
# 9
#
#
# Unión La CaleraChile Chile
#
#
# 2ª
#
# 2017
# 9
# 1
# 0
# --
# --
# --
# --
# --
# --
#
# 9
#
# 1
#
# 0
#
#
# Total club
# 23
# 3
# 4
# 6
# 0
# 0
# 2
# 0
# 0
# 31
# 3
# 4
#
#
# Oriente PetroleroBolivia Bolivia
#
#
# 1.ª
#
# 2018
# 0
# 0
# 0
# 0
# 0
# 0
# --
# --
# --
#
# 0
#
# 0
#
# 0
#
#
# Total club
# 0
# 0
# 0
# --
# --
# --
# --
# --
# --
# 9
# 1
# 0
#
#
# Total carrera
# 378
# 62
# 37
# 15
# 2
# -
# 8
# 2
# -
# 401
# 66
# 37
#
#
#
# (1) Incluye datos de Copa de Brasil y Copa Chile.
# (2) Incluye datos de Copa Sudamericana.
#
# Títulos[editar]
# Nacionales[editar]
#
#
# Título
#
# Club
#
# País
#
# Año
#
#
# Primera B
#
# Unión La Calera [9]​
#
# Chile Chile
#
# Transición 2017
#
# Referencias[editar]
#
# ↑ Yahoo! Respuestas, ed. (3 de septiembre de 2010). «¿Qué relación tienen Mauro Rosales y Paulo Rosales?».
#
# ↑ Twicsy, ed. (28 de junio de 2012). «Paulo Rosales no renueva con Unión».
#
# ↑ Diario Olé, ed. (7 de julio de 2012). «Bochini: "Va a rendir más si juega de enganche».
#
# ↑ InfiernoRojo, ed. (10 de julio de 2012). «Firmó Paulo Rosales».
#
# ↑ InfiernoRojo, ed. (22 de agosto de 2012). «¡Te espero en Avellaneda!». Archivado desde el original el 25 de agosto de 2012.
#
# ↑ InfiernoRojo, ed. (30 de septiembre de 2012). «Los goles de Farías en HD». Archivado desde el original el 2 de octubre de 2012.
#
# ↑ InfiernoRojo, ed. (30 de septiembre de 2012). «¡10 puntos!». Archivado desde el original el 2 de octubre de 2012.
#
# ↑ http://www.ellitoral.com/index.php/diarios/2005/10/01/deportes/DEPO-02.html
#
# ↑ futbolprimerabchile.cl. / «Quiere evitar el descenso: Unión La Calera suma a talentoso volante de creación».
#
#
# Control de autoridades
# : Q10346803
#
#
#
#
#
#
# 						Obtenido de «https://es.wikipedia.org/w/index.php?title=Paulo_Rosales&oldid=107945742»
# Categorías: Nacidos en 1984HombresCoscoínosFutbolistas de la provincia de Córdoba (Argentina)Futbolistas del Club Atlético Newell's Old BoysFutbolistas del Club Atlético Unión (Santa Fe)Futbolistas del Club Atlético Talleres (Córdoba)Futbolistas del Olympiakos VolouFutbolistas del Club Atlético IndependienteFutbolistas del Esporte Clube BahiaFutbolistas del Club OlimpoFutbolistas del Club de Deportes Unión La Calera en los años 2010Futbolistas del Club de Deportes Santiago Wanderers en los años 2010Categorías ocultas: Wikipedia:Artículos con datos por trasladar a WikidataWikipedia:Mantenimiento de la plantilla Altura (metro)Personas vivas
#
#
#
# Menú de navegación
#
#
# Herramientas personales
#
# No has accedidoDiscusiónContribucionesCrear una cuentaAcceder
#
#
#
# Espacios de nombres
#
# ArtículoDiscusión
#
#
#
#
# Variantes
#
#
#
#
#
#
#
#
#
# Vistas
#
# LeerEditarVer historial
#
#
#
# Más
#
#
#
#
#
#
#
# Buscar
#
#
#
#
#
#
#
#
#
#
#
# Navegación
#
#
# PortadaPortal de la comunidadActualidadCambios recientesPáginas nuevasPágina aleatoriaAyudaDonacionesNotificar un error
#
#
#
# Imprimir/exportar
#
#
# Crear un libroDescargar como PDFVersión para imprimir
#
#
#
# Herramientas
#
#
# Lo que enlaza aquíCambios en enlazadasSubir archivoPáginas especialesEnlace permanenteInformación de la páginaElemento de WikidataCitar esta página
#
#
#
# En otros idiomas
#
#
# EnglishPortuguêsТоҷикӣ
# Editar enlaces
#
#
#
#
#
#  Esta página se editó por última vez el 19 may 2018 a las 08:56.
# El texto está disponible bajo la Licencia Creative Commons Atribución Compartir Igual 3.0;
# pueden aplicarse cláusulas adicionales. Al usar este sitio, usted acepta nuestros términos de uso y nuestra política de privacidad. Wikipedia® es una marca registrada de la Fundación Wikimedia, Inc., una organización sin ánimo de lucro.
#
#
# Política de privacidad
# Acerca de Wikipedia
# Limitación de responsabilidad
# Desarrolladores
# Declaración de cookies
# Versión para móviles
#
#
#
#
#
#
#
#
#
# (window.RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.340","walltime":"0.425","ppvisitednodes":{"value":3541,"limit":1000000},"ppgeneratednodes":{"value":0,"limit":1500000},"postexpandincludesize":{"value":30489,"limit":2097152},"templateargumentsize":{"value":2610,"limit":2097152},"expansiondepth":{"value":22,"limit":40},"expensivefunctioncount":{"value":0,"limit":500},"unstrip-depth":{"value":0,"limit":20},"unstrip-size":{"value":9967,"limit":5000000},"entityaccesscount":{"value":1,"limit":400},"timingprofile":["100.00%  296.010      1 -total"," 59.62%  176.489      1 Plantilla:Ficha_de_deportista"," 56.45%  167.108      1 Plantilla:Ficha"," 18.74%   55.462     13 Plantilla:Propiedad"," 16.86%   49.913      1 Plantilla:Listaref"," 12.81%   37.905      1 Plantilla:NF"," 12.27%   36.323      8 Plantilla:Cita_web","  8.86%   26.221      1 Plantilla:Control_de_autoridades","  7.92%   23.453      6 Plantilla:Reemplazar","  4.89%   14.473      2 Plantilla:Desvincular"]},"scribunto":{"limitreport-timeusage":{"value":"0.098","limit":"10.000"},"limitreport-memusage":{"value":3777553,"limit":52428800}},"cachereport":{"origin":"mw1241","timestamp":"20180829223537","ttl":3600,"transientcontent":true}}});mw.config.set({"wgBackendResponseTime":523,"wgHostname":"mw1241"});});

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(request.content, 'html.parser')

print(soup.get_text())
