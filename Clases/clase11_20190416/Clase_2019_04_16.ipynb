# %% [markdown]
# # 2019-04-16 (martes)
#
# ### Anuncios
# - Mañana empieza Lab4. Entrega viernes 26
#
# - Leer Capítulo 1 de "Fundamentals of Database Systems" de Elmasri y Navathe.
#
# ### Hoy:
# - Pandas

# %% [markdown]
# ### Bases de Datos en Python
#
# Ya trabajamos con algunas estructuras de datos básicas en python (listas, tuplas, diccionarios), y también aprendimos a crear nuestras propias estructuras de datos (objetos).
#
# Existen un tipo de estructura de datos a la que estamos muy acostumbrados, que llamamos coloquialmente "base de datos". Estos objetos usualmente tienen disponibles, **para los usuarios de los datos**, las siguientes operaciones:
#
# - Creación de nuevas columnas ("variables")
# - Análisis de subconjuntos de datos (por ej, "filtros" en Excel)
# - Tablas resúmen (por ej, "Tabla dinámica" en Excel -- "collapse" en Stata)
# - Cruce de datos (por ej, "buscarv" o "buscarh" de Excel) o union de bases de datos ("append" de Stata)
#
# Para lo anterior, existe una librería muy potente de Python llamada "Pandas".

# %% [markdown]
# ### Ejercicio en clase
# Contemos el número de transacciones por fecha...

# %%
#cargamos datos del ejercicio

path = r'C:\Users\calvarad\GIT_EAE253B\eae253b\Clases\clase11_20190416/transactions_small.csv'

file = open(path)

header = file.readline()

i = 0
dicc_fechas = {}

for line in file:
    i = i + 1
        
    rid,chain,dept,category,company,brand,fecha,productsize,productmeasure,purchasequantity,purchaseamount = line.strip().split(',')

    dicc_fechas[fecha] = dicc_fechas.get(fecha, 0) + 1 


#guardo las transacciones por fecha

lista_transacciones = []

for fecha, val in dicc_fechas.items():
    
    lista_transacciones.append((fecha, val))

print(lista_transacciones)
# Out:
# [('2012-03-02', 256), ('2012-03-03', 231), ('2012-03-04', 316), ('2012-03-05', 203), ('2012-03-06', 163), ('2012-03-07', 138), ('2012-03-08', 180), ('2012-03-09', 215), ('2012-03-10', 293), ('2012-03-11', 262), ('2012-03-12', 170), ('2012-03-14', 142), ('2012-03-15', 183), ('2012-03-16', 241), ('2012-03-17', 228), ('2012-03-18', 305), ('2012-03-19', 171), ('2012-03-20', 141), ('2012-03-21', 164), ('2012-03-22', 140), ('2012-03-23', 203), ('2012-03-24', 253), ('2012-03-25', 260), ('2012-03-26', 163), ('2012-03-27', 168), ('2012-03-28', 172), ('2012-03-30', 248), ('2012-03-31', 233), ('2012-04-01', 278), ('2012-04-02', 244), ('2012-04-04', 193), ('2012-04-05', 189), ('2012-04-06', 263), ('2012-04-07', 356), ('2012-04-08', 213), ('2012-04-09', 159), ('2012-04-10', 174), ('2012-04-12', 157), ('2012-04-13', 163), ('2012-04-14', 226), ('2012-04-15', 301), ('2012-04-16', 195), ('2012-04-20', 210), ('2012-04-21', 207), ('2012-04-24', 198), ('2012-04-25', 121), ('2012-04-27', 221), ('2012-04-28', 269), ('2012-04-29', 273), ('2012-04-30', 212), ('2012-05-01', 185), ('2012-05-02', 166), ('2012-05-03', 165), ('2012-05-04', 280), ('2012-05-05', 260), ('2012-05-06', 331), ('2012-05-07', 191), ('2012-05-09', 167), ('2012-05-11', 196), ('
# %% [markdown]
# Y si ocupamos pandas??

# %%
import pandas as pd

df = pd.read_csv(path)

# %%
display(df.head())
# Out:
#       id  chain  dept  category     company  brand        date  productsize  \
# 0  86246    205    55      5555   107684070  32094  2012-03-02         16.0
# 1  86246    205    73      7344  1068142161  20285  2012-03-02          8.0
# 2  86246    205    41      4120   101116616  15266  2012-03-02          6.0
# 3  86246    205    26      2630   103700030  14647  2012-03-02         56.0
# 4  86246    205     9       907   107225070  12465  2012-03-02         20.0
#
#   productmeasure  purchasequantity  purchaseamount
# 0             OZ                 2           10.38
# 1             CT                 1            5.79
# 2             OZ                 1            0.89
# 3             CT                 1            1.00
# 4             OZ                 1            2.99

# %%
df.groupby('date').count()
# Out:
#              id  chain  dept  category  company  brand  productsize  \
# date
# 2012-03-02  256    256   256       256      256    256          256
# 2012-03-03  231    231   231       231      231    231          231
# 2012-03-04  316    316   316       316      316    316          316
# 2012-03-05  203    203   203       203      203    203          203
# 2012-03-06  163    163   163       163      163    163          163
# 2012-03-07  138    138   138       138      138    138          138
# 2012-03-08  180    180   180       180      180    180          180
# 2012-03-09  215    215   215       215      215    215          215
# 2012-03-10  293    293   293       293      293    293          293
# 2012-03-11  262    262   262       262      262    262          262
# 2012-03-12  170    170   170       170      170    170          170
# 2012-03-13  150    150   150       150      150    150          150
# 2012-03-14  142    142   142       142      142    142          142
# 2012-03-15  183    183   183       183      183    183          183
# 2012-03-16  241    241   241       241      241    241          241
# 2012-03-17  228    228   228       228      228    228          228
# 2012-03-18  305    305   305       305      305    305          305
# 2012-03-19  171    171   171       171      171    171          171
# 2012-03-20  141    141   141       141      141    141          141
# 2012-03-21  164    164   164       164      164    164          164
# 2012-03-22  140    140   140       140      140    140          140
# 2012-03-23  203    203   203       203      203    203          203
# 2012-03-24  253    253   253       253      253    253          253
# 2012-03-25  260    260   260       260      260    260          260
# 2012-03-26  163    163   163       163      163    163          163
# 2012-03-27  168    168   168       168      168    168          168
# 2012-03-28  172    172   172       172      172    172          172
# 2012-03-29  153    153   153       153      153    153          153
# 2012-03-30  248    248   248       248      248    248          248
# 2012-03-31  233    233   233       233      233    233          233
# ...         ...    ...   ...       ...      ...    ...          ...
# 2013-06-24   31     31    31        31       31     31           31
# 2013-06-25   26     26    26        26       26     26           26
# 2013-06-26   21     21    21        21       21     21           21
# 2013-06-27   36     36    36        36       36     36           36
# 2013-06-28   13     13    13        13       13     13           13
# 2013-06-29   31     31    31        31       31     31           31
# 2013-06-30   39     39    39        39       39     39           39
# 2013-07-01   10     10    10        10       10     10           10
# 2013-07-02   39     39    39        39       39     39           39
# 2013-07-03   24     24    24        24       24     24           24
# 2013-07-04   27     27    27        27       27     27           27
# 2013-07-05   32     32    32        32       32     32           32
# 2013-07-06   57     57    57        57       57     57           57
# 2013-07-07   28     28    28        28       28     28           28
# 2013-07-08   18     18    18        18       18     18           18
# 2013-07-09   24     24    24        24       24     24           24
# 2013-07-10   22     22    22        22       22     22           22
# 2013-07-11   19     19    19        19       19     19           19
# 2013-07-12   49     49    49        49       49     49           49
# 2013-07-13   15     15    15        15       15     15           15
# 2013-07-14   15     15    15        15       15     15           15
# 2013-07-15   16     16    16        16       16     16           16
# 2013-07-16   33     33    33        33       33     33           33
# 2013-07-17   16     16    16        16       16     16           16
# 2013-07-18   17     17    17        17       17     17           17
# 2013-07-19   18     18    18        18       18     18           18
# 2013-07-20   46     46    46        46       46     46           46
# 2013-07-21   17     17    17        17       17     17           17
# 2013-07-22   13     13    13        13       13     13           13
# 2013-07-23   23     23    23        23       23     23           23
#
#             productmeasure  purchasequantity  purchaseamount
# date
# 2012-03-02             254               256             256
# 2012-03-03             224               231             231
# 2012-03-04             306               316             316
# 2012-03-05             200               203             203
# 2012-03-06             162               163             163
# 2012-03-07             135               138             138
# 2012-03-08             178               180             180
# 2012-03-09             210               215             215
# 2012-03-10             288               293             293
# 2012-03-11             260               262             262
# 2012-03-12             168               170             170
# 2012-03-13             149               150             150
# 2012-03-14             142               142             142
# 2012-03-15             178               183             183
# 2012-03-16             235               241             241
# 2012-03-17             221               228             228
# 2012-03-18             300               305             305
# 2012-03-19             171               171             171
# 2012-03-20             138               141             141
# 2012-03-21             162               164             164
# 2012-03-22             137               140             140
# 2012-03-23             202               203             203
# 2012-03-24             244               253             253
# 2012-03-25             255               260             260
# 2012-03-26             162               163             163
# 2012-03-27             167               168             168
# 2012-03-28             169               172             172
# 2012-03-29             151               153             153
# 2012-03-30             245               248             248
# 2012-03-31             228               233             233
# ...                    ...               ...             ...
# 2013-06-24              30                31              31
# 2013-06-25              26                26              26
# 2013-06-26              21                21              21
# 2013-06-27              36                36              36
# 2013-06-28              13                13              13
# 2013-06-29              31                31              31
# 2013-06-30              39                39              39
# 2013-07-01              10                10              10
# 2013-07-02              39                39              39
# 2013-07-03              24                24              24
# 2013-07-04              27                27              27
# 2013-07-05              32                32              32
# 2013-07-06              56                57              57
# 2013-07-07              28                28              28
# 2013-07-08              18                18              18
# 2013-07-09              23                24              24
# 2013-07-10              22                22              22
# 2013-07-11              19                19              19
# 2013-07-12              48                49              49
# 2013-07-13              15                15              15
# 2013-07-14              14                15              15
# 2013-07-15              15                16              16
# 2013-07-16              33                33              33
# 2013-07-17              16                16              16
# 2013-07-18              17                17              17
# 2013-07-19              17                18              18
# 2013-07-20              45                46              46
# 2013-07-21              17                17              17
# 2013-07-22              13                13              13
# 2013-07-23              22                23              23
#
# [509 rows x 10 columns]

# %% [markdown]
# Graficar? No hay problema:

# %%
#esta linea me permite graficar en el mismo notebook..
# %matplotlib inline

tabla_por_fecha = df.groupby('date').count()['id']

tabla_por_fecha.plot()

# %% [markdown]
# Exportar a Excel? No hay problema

# %%
tabla_por_fecha.to_excel('ventas_por_fecha.xlsx')

# %% [markdown]
# ## Indices
#
# Un elemento clave detrás de las bases de datos son los "indices". Es la forma que tienen las bases de datos de "buscar" la información de manera eficiente, permitiendo esto que las operaciones sobre la base de datos sea lo más rápido posible.

# %%
tabla_por_fecha.index
# Out:
# Index(['2012-03-02', '2012-03-03', '2012-03-04', '2012-03-05', '2012-03-06',
#        '2012-03-07', '2012-03-08', '2012-03-09', '2012-03-10', '2012-03-11',
#        ...
#        '2013-07-14', '2013-07-15', '2013-07-16', '2013-07-17', '2013-07-18',
#        '2013-07-19', '2013-07-20', '2013-07-21', '2013-07-22', '2013-07-23'],
#       dtype='object', name='date', length=509)

# %%
type(tabla_por_fecha)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Busquemos la fecha de forma "ineficiente"

# %%
def busca_fecha(fecha_a_buscar, lista_transacciones):
    '''
    Busca el número de transacciones para una fecha
    en particular
    '''
    
    for fecha, val in lista_transacciones:
        if fecha == fecha_a_buscar:
            return val

    return 0

# %%
fecha_a_buscar = '2013-07-16'

busca_fecha(fecha_a_buscar, lista_transacciones)
# Out:
# 33

# %%
tabla_por_fecha.loc[fecha_a_buscar]
# Out:
# 33

# %%
#ventas del un dia particular

# %timeit busca_fecha(fecha_a_buscar, lista_transacciones)

# %timeit tabla_por_fecha.loc[fecha_a_buscar]

# %timeit dicc_fechas[fecha_a_buscar]
# Out:
# 16.6 µs ± 258 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 23.2 µs ± 4.01 µs per loop (mean ± std. dev. of 7 runs, 100000 loops each)
# 45.3 ns ± 3.64 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %% [markdown]
# ## Detour: geopandas
#
# Existe una librería complementaria a Pandas llamada "GeoPandas". Dicha librería nos permite hacer gráficos (y cálculos) sobre geometrías (por ejemplo, "mapas").

# %%
#CORRER ESTO SOLO EN COLAB.RESEARCH

# !apt-get -qq install libspatialindex-dev
# !pip install -q pysal
# !pip install -q Rtree
# !pip install -q shapely
# !pip install -q geopandas
# !pip install -q descartes

import pandas as pd
import geopandas as gp

#mapa del mundo

world = gp.read_file(gp.datasets.get_path('naturalearth_lowres'))

world = world[world.continent != 'Antarctica']

world.plot();
world.head()
# Out:
# "apt-get" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.
# smart-open 1.6.0 requires bz2file, which is not installed.
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# smart-open 1.6.0 requires bz2file, which is not installed.
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# smart-open 1.6.0 requires bz2file, which is not installed.
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# smart-open 1.6.0 requires bz2file, which is not installed.
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# smart-open 1.6.0 requires bz2file, which is not installed.
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
#       pop_est      continent                  name iso_a3  gdp_md_est  \
# 0  28400000.0           Asia           Afghanistan    AFG     22270.0
# 1  12799293.0         Africa                Angola    AGO    110300.0
# 2   3639453.0         Europe               Albania    ALB     21810.0
# 3   4798491.0           Asia  United Arab Emirates    ARE    184300.0
# 4  40913584.0  South America             Argentina    ARG    573900.0
#
#                                             geometry
# 0  POLYGON ((61.21081709172574 35.65007233330923,...
# 1  (POLYGON ((16.32652835456705 -5.87747039146621...
# 2  POLYGON ((20.59024743010491 41.85540416113361,...
# 3  POLYGON ((51.57951867046327 24.24549713795111,...
# 4  (POLYGON ((-65.50000000000003 -55.199999999999...

# %%
ax = world.plot(column='pop_est', cmap='Purples', figsize=(20,20), linewidth=0.25, edgecolor='black')
ax.axis('off')
# Out:
# (-197.99999999999997,
#  198.00000000000014,
#  -62.57467799999996,
#  90.60797800000002)
